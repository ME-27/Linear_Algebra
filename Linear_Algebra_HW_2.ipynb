# %% [markdown]
# # Домашнее задание № 2

# %% [markdown]
# ## по дисциплине: Линейная алгебра

# %% [markdown]
# ## Матрицы и матричные операции

# %% [markdown]
# ### выполнил: Евгений Кириллов

# %% [markdown]
# # Часть 1

# %% [markdown]
# __1.__ Установить, какие произведения матриц $AB$ и $BA$ определены, и найти размерности полученных матриц:
#
#    а) $A$ — матрица $4\times 2$, $B$ — матрица $4\times 2$;
#
#    б) $A$ — матрица $2\times 5$, $B$ — матрица $5\times 3$;
#
#    в) $A$ — матрица $8\times 3$, $B$ — матрица $3\times 8$;
#
#    г) $A$ — квадратная матрица $4\times 4$, $B$ — квадратная матрица $4\times 4$.

# %% [markdown]
# #### а)

# %% [markdown]
# матрицу A нельзя умножить на матрицу B (и наоборот) т.к. число столбцов одной матрицы не равно числу строк другой

# %% [markdown]
# #### б)

# %% [markdown]
# $A \cdot B$ имеет размерность $2 \times 3$

# %% [markdown]
# $B \cdot A$ перемножить нельзя

# %% [markdown]
# #### в)

# %% [markdown]
# $A \cdot B$ имеет размерность $8 \times 8$

# %% [markdown]
# $B \cdot A$ имеет размерность $3 \times 3$

# %% [markdown]
# #### г)

# %% [markdown]
# $A \cdot B$ имеет размерность $4 \times 4$

# %% [markdown]
# $B \cdot A$ имеет размерность $4 \times 4$

# %% [markdown]
# __2.__ Найти сумму и произведение матриц $A=\begin{pmatrix}
# 1 & -2\\
# 3 & 0
# \end{pmatrix}$ и $B=\begin{pmatrix}
# 4 & -1\\
# 0 & 5
# \end{pmatrix}.$

# %% [markdown]
# ### $$A+B=B+A=\begin{pmatrix}1 & -2\\ 3 & 0\end{pmatrix} + \begin{pmatrix}4 & -1\\ 0 & 5\end{pmatrix} = \begin{pmatrix}1+4 & -2+(-1)\\ 3+0 & 0+5\end{pmatrix} = \begin{pmatrix}5 & -3\\ 3 & 5\end{pmatrix}$$

# %% [markdown]
# ### $$A \cdot B=\begin{pmatrix}1 & -2\\ 3 & 0\end{pmatrix} \cdot \begin{pmatrix}4 & -1\\ 0 & 5\end{pmatrix} = \begin{pmatrix}1\times4 + (-2)\times0& 1\times(-1)+(-2)\times5\\ 3\times4 + 0\times0 & 3\times(-1)+0\times5\end{pmatrix} = \begin{pmatrix}4 & -11\\ 12 & -3\end{pmatrix}$$

# %% [markdown]
# ### $$B \cdot A=\begin{pmatrix}4 & -1\\ 0 & 5\end{pmatrix} \cdot \begin{pmatrix}1 & -2\\ 3 & 0\end{pmatrix} = \begin{pmatrix}4\times1 + (-1)\times3& 4\times(-2) + (-1)\times0\\ 0\times1 + 5\times3 & 0\times(-2)+5\times0\end{pmatrix} = \begin{pmatrix}1 & -8\\ 15 & 0\end{pmatrix}$$

# %% [markdown]
# #### проверим с помощью numpy:

# %%
import numpy as np

# %%
A = np.array([[1, -2], [3, 0]])
B = np.array([[4, -1], [0, 5]])

# %%
A
# Out:
# array([[ 1, -2],
#        [ 3,  0]])

# %%
B
# Out:
# array([[ 4, -1],
#        [ 0,  5]])

# %%
A + B
# Out:
# array([[ 5, -3],
#        [ 3,  5]])

# %%
np.dot(A, B)
# Out:
# array([[  4, -11],
#        [ 12,  -3]])

# %%
np.dot(B, A)
# Out:
# array([[ 1, -8],
#        [15,  0]])

# %% [markdown]
# __3.__ Из закономерностей сложения и умножения матриц на число можно сделать вывод, что матрицы одного размера образуют линейное пространство. Вычислить линейную комбинацию $3A-2B+4C$ для матриц $A=\begin{pmatrix}
# 1 & 7\\
# 3 & -6
# \end{pmatrix}$, $B=\begin{pmatrix}
# 0 & 5\\
# 2 & -1
# \end{pmatrix}$, $C=\begin{pmatrix}
# 2 & -4\\
# 1 & 1
# \end{pmatrix}.$

# %% [markdown]
# ### $$3A−2B+4C=3\cdot\begin{pmatrix}1 & 7\\ 3 & -6\end{pmatrix} + (-2)\cdot\begin{pmatrix}0 & 5\\ 2 & -1\end{pmatrix}  + 4\cdot\begin{pmatrix}2 & -4\\ 1 & 1\end{pmatrix}= $$

# %% [markdown]
# ### $$=\begin{pmatrix}3 & 21\\ 9 & -18\end{pmatrix} + \begin{pmatrix}0 & -10\\ -4 & 2\end{pmatrix}  + \begin{pmatrix}8 & -16\\ 4 & 4\end{pmatrix}= \begin{pmatrix}11 & -5\\ 9 & -12\end{pmatrix}$$

# %% [markdown]
# #### проверим с помощью numpy:

# %%
A = np.array([[1, 7], [3, -6]])
B = np.array([[0, 5], [2, -1]])
C = np.array([[2, -4], [1, 1]])

# %%
A
# Out:
# array([[ 1,  7],
#        [ 3, -6]])

# %%
B
# Out:
# array([[ 0,  5],
#        [ 2, -1]])

# %%
C
# Out:
# array([[ 2, -4],
#        [ 1,  1]])

# %%
3 * A + (-2) * B + 4 * C
# Out:
# array([[ 11,  -5],
#        [  9, -12]])

# %% [markdown]
# __4.__ Дана матрица $A=\begin{pmatrix}
# 4 & 1\\
# 5 & -2\\
# 2 & 3
# \end{pmatrix}$.
# Вычислить $AA^{T}$ и $A^{T}A$.

# %% [markdown]
# ### $$A^{T} = \begin{pmatrix}4 & 5 & 2\\ 1 & -2 & 3\end{pmatrix}$$

# %% [markdown]
# ### $$AA^{T} = \begin{pmatrix}4 & 1\\ 5 & -2\\ 2 & 3\end{pmatrix} \cdot \begin{pmatrix}4 & 5 & 2\\ 1 & -2 & 3\end{pmatrix}=$$

# %% [markdown]
# ### $$= \begin{pmatrix}4\times4+1\times1 & 4\times5+1\times(-2) & 4\times2+1\times3\\ 5\times4+(-2)\times1 & 5\times5+(-2)\times(-2) & 5\times2+(-2)\times3\\2\times4+3\times1 & 2\times5+3\times(-2) & 2\times2+3\times3\end{pmatrix} =$$

# %% [markdown]
# ### $$= \begin{pmatrix}17 & 18 & 11\\ 18 & 29 & 4\\11 & 4 & 13\end{pmatrix}$$

# %% [markdown]
# ### $$A^{T}A = \begin{pmatrix}4 & 5 & 2\\ 1 & -2 & 3\end{pmatrix} \cdot \begin{pmatrix}4 & 1\\ 5 & -2\\ 2 & 3\end{pmatrix}=$$

# %% [markdown]
# ### $$=\begin{pmatrix}4\times4+5\times5+2\times2 & 4\times1+5\times(-2)+2\times3\\ 1\times4+(-2)\times5+3\times2 & 1\times1+(-2)\times(-2)+3\times3\end{pmatrix}=\begin{pmatrix}45 & 0\\ 0 & 14\end{pmatrix}$$

# %% [markdown]
# #### проверим с помощью numpy:

# %%
A = np.array([[4, 1], [5, -2], [2, 3]])

# %%
A
# Out:
# array([[ 4,  1],
#        [ 5, -2],
#        [ 2,  3]])

# %%
A.T
# Out:
# array([[ 4,  5,  2],
#        [ 1, -2,  3]])

# %%
np.dot(A, A.T)
# Out:
# array([[17, 18, 11],
#        [18, 29,  4],
#        [11,  4, 13]])

# %%
np.dot(A.T, A)
# Out:
# array([[45,  0],
#        [ 0, 14]])

# %% [markdown]
# __5*.__ Написать на Python функцию для перемножения двух произвольных матриц, не используя NumPy.

# %%
def matrixes_product(A, B):
    
    # проверяем на возможность произведения
    if len(A) != len(B[0]):
        print('матрицы нельзя перемножить')
        return None
    
    # транспонируем матрицу B - так удобнее потом перемножать элементы двух матриц
    B_trans = []
    for i in range(len(B[0])):
        new_line = []
        for ii in range(len(B)):
            new_line.append(B[ii][i])
        B_trans.append(new_line)
    
    # создаём болванку под итоговую матрицу
    m_product = [[0] * len(A) for _ in range(len(A))]
    
    # заполняем болванку
    for i in range(len(m_product)):
        for ii in range(len(m_product[i])):
            m_product[i][ii] = [element for element in zip([m for m in A[i]], [n for n in B_trans[ii]])]
            print(m_product[i][ii])  # демонстрация механизма рассчёта каждого элемента итоговой матрицы
            m_product[i][ii] = sum([element[0] * element[1] for element in m_product[i][ii]])
            print(m_product[i][ii])  # демонстрация механизма рассчёта каждого элемента итоговой матрицы
        
    return m_product

# %% [markdown]
# #### проверка работы функции

# %% [markdown]
# возьмём матрицы A и B из второго задания

# %%
A = [[1, -2], [3, 0]]
B = [[4, -1], [0, 5]]

# %%
matrixes_product(A, B)
# Out:
# [(1, 4), (-2, 0)]
# 4
# [(1, -1), (-2, 5)]
# -11
# [(3, 4), (0, 0)]
# 12
# [(3, -1), (0, 5)]
# -3
# [[4, -11], [12, -3]]

# %%
matrixes_product(B, A)
# Out:
# [(4, 1), (-1, 3)]
# 1
# [(4, -2), (-1, 0)]
# -8
# [(0, 1), (5, 3)]
# 15
# [(0, -2), (5, 0)]
# 0
# [[1, -8], [15, 0]]

# %% [markdown]
# возьмём матрицы A и AT из четвёртого задания

# %%
A = [[4, 1], [5, -2], [2, 3]]
AT = [[4, 5, 2], [1, -2, 3]]

# %%
matrixes_product(A, AT)
# Out:
# [(4, 4), (1, 1)]
# 17
# [(4, 5), (1, -2)]
# 18
# [(4, 2), (1, 3)]
# 11
# [(5, 4), (-2, 1)]
# 18
# [(5, 5), (-2, -2)]
# 29
# [(5, 2), (-2, 3)]
# 4
# [(2, 4), (3, 1)]
# 11
# [(2, 5), (3, -2)]
# 4
# [(2, 2), (3, 3)]
# 13
# [[17, 18, 11], [18, 29, 4], [11, 4, 13]]

# %%
matrixes_product(AT, A)
# Out:
# [(4, 4), (5, 5), (2, 2)]
# 45
# [(4, 1), (5, -2), (2, 3)]
# 0
# [(1, 4), (-2, 5), (3, 2)]
# 0
# [(1, 1), (-2, -2), (3, 3)]
# 14
# [[45, 0], [0, 14]]

# %% [markdown]
# #### всё работает!

# %% [markdown]
# # Часть 2

# %% [markdown]
# __1.__ Вычислить определитель:

# %% [markdown]
# #### a)

# %% [markdown]
# ### $$\begin{vmatrix}sinx & -cosx\\ cosx & sinx\end{vmatrix} = sin(x) \cdot sin(x) - (-cos(x)) \cdot cos(x) = sin^{2}(x) + cos^{2}(x) = 1$$

# %% [markdown]
# #### б)

# %% [markdown]
# т.к. матрица треугольная, то определитель равен произведению элементов основной диагонали

# %% [markdown]
# ### $$\begin{vmatrix}4 & 2 & 3\\ 0 & 5 & 1\\ 0 & 0 & 9\end{vmatrix}= 4 \cdot 5 \cdot 9= 180$$

# %% [markdown]
# #### в)

# %% [markdown]
# ### $$\begin{vmatrix}1 & 2 & 3\\ 4 & 5 & 6\\ 7 & 8 & 9\end{vmatrix}=1\cdot\begin{vmatrix}5 & 6\\ 8 & 9\end{vmatrix}-2\cdot\begin{vmatrix}4 &6\\ 7 & 9\end{vmatrix}+3\cdot\begin{vmatrix}4 & 5\\ 7 & 8\end{vmatrix}=$$

# %% [markdown]
# ### $$=1\cdot(45-48)-2\cdot(36-42)+3\cdot(32-35)=-3+12-9=0$$

# %% [markdown]
# __2.__ Определитель матрицы $A$ равен $4$. Найти:

# %% [markdown]
# а) $det(A^{2})$;

# %% [markdown]
# т.к. для двух квадратных матриц одинакового размера

# %% [markdown]
# ### $$det(AB)=detA\cdot detB$$

# %% [markdown]
# тогда:

# %% [markdown]
# ### $$det(A^{2})=det(AA)=detA\cdot detA=4\cdot4=16$$

# %% [markdown]
# б) $det(A^{T})$

# %% [markdown]
# т.к. определитель транспонированной матрицы равен определителю исходной:

# %% [markdown]
# ### $$detA^{T}=detA=4$$

# %% [markdown]
# в) $det(2A)$

# %% [markdown]
# ### $$det(2A)=2det(A)=8$$

# %% [markdown]
# __3.__  Доказать, что матрица
#
# $$\begin{pmatrix}-2 & 7 & -3\\ 4 & -14 & 6\\ -3 & 7 & 13\end{pmatrix}$$
#
# вырожденная.

# %% [markdown]
# т.к. матрица называется сингулярной, или вырожденной, если ее определитель равен нулю, тогда найдём определительнашей матрицы

# %%
A = np.array([[-2, 7, -3], [4, -14, 6], [-3, 7, 13]])

# %%
np.linalg.det(A)
# Out:
# 0.0

# %% [markdown]
# или

# %% [markdown]
# если две строки (столбца) матрицы линейно зависимы, то определитель этой матрицы равен нулю, а соответственно матрица является вырожденной

# %% [markdown]
# первая и вторая строки данной матрицы линейно засимы: вторая это первая умноженная на -2

# %% [markdown]
# __4.__ Найти ранг матрицы:

# %% [markdown]
# а) $\begin{pmatrix}1 & 2 & 3\\ 1 & 1 & 1\\ 2 & 3 & 4\end{pmatrix}$

# %% [markdown]
# 3я строка является сложением 1й и 2й строк, поэтому её можно выбросить

# %% [markdown]
# ранг матрицы = 2

# %% [markdown]
# проверим:

# %%
A = np.array([[1, 2, 3], [1, 1, 1], [2, 3, 4]])
np.linalg.matrix_rank(A)
# Out:
# 2

# %% [markdown]
# б) $\begin{pmatrix}0 & 0 & 2 & 1\\ 0 & 0 & 2 & 2\\ 0 & 0 & 4 & 3\\ 2 & 3 & 5 & 6\end{pmatrix}$

# %% [markdown]
# 3я строка является сложением 1й и 2й строк, поэтому её можно выбросить

# %% [markdown]
# ранг матрицы = 3

# %% [markdown]
# проверим:

# %%
A = np.array([[0, 0, 2, 1], [0, 0, 2, 2], [0, 0, 4, 3], [2, 3, 5, 6]])
np.linalg.matrix_rank(A)
# Out:
# 3
