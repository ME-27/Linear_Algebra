# %% [markdown]
# # Домашнее задание № 2

# %% [markdown]
# ## по дисциплине: Линейная алгебра

# %% [markdown]
# ## Матрицы и матричные операции

# %% [markdown]
# ### выполнил: Евгений Кириллов

# %% [markdown]
# # Часть 1

# %%
в процессе
