# %% [markdown]
# # Домашнее задание № 1

# %% [markdown]
# ## по дисциплине: Линейная алгебра

# %% [markdown]
# ## Линейное пространство

# %% [markdown]
# ### выполнил: Евгений Кириллов

# %% [markdown]
# День добрый! ДЗ делаю, не успел к назначенному сроку, будет к завтрашнему дню. Прикрепляю этот пустой файл, чтобы потом в поддержку не писать для сдачи. Спасибо за понимание!
