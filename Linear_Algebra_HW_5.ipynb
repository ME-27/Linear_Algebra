# %% [markdown]
# # Домашнее задание № 5

# %% [markdown]
# ## по дисциплине: Линейная алгебра

# %% [markdown]
# ## Сингулярное разложение матриц

# %% [markdown]
# ### выполнил: Евгений Кириллов

# %% [markdown]
# немного не успел, ДЗ будет чуть попозже

# %% [markdown]
# __1.__ Найти с помощью NumPy SVD для матрицы

# %% [markdown]
# ### $$\begin{pmatrix}1 & 2 & 0\\ 0 & 0 & 5\\ 3 & -4 & 2\\ 1 & 6 & 5\\ 0 & 1 & 0\end{pmatrix}.$$

# %% [markdown]
# __2.__ Для матрицы из предыдущего задания найти:
#
#     а) евклидову норму;
#
#     б) норму Фробениуса.
